# %% [markdown]
# <a href="https://colab.research.google.com/github/niz11/Bachelor_Thesis_Colab_Files/blob/main/Visualize_5_frames_composite_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# Load encoding
X = np.load('drive/My Drive/dataset_5_frame_seq_faces/X_5.npy')
y = np.load('drive/My Drive/dataset_5_frame_seq_faces/Y_label_5.npy')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
import keras
from keras.layers import Input, Flatten, Dense,LSTM,TimeDistributed,RepeatVector
from keras.models import Model,Sequential
from keras.utils import plot_model


def create_model(encoding_length=64,sequence_length=10):
  # Define an input sequence and process it.
  encoder_inputs = Input(shape=(sequence_length, encoding_length))
  encoder = LSTM(encoding_length, return_sequences=True)(encoder_inputs)
  encoder_outputs, state_h, state_c  = LSTM(encoding_length, return_state=True, name='encoder')(encoder)
  encoder_states = [state_h, state_c]
  clssifier  = Dense(7, activation='softmax')(encoder_outputs)

  model = Model(inputs=encoder_inputs, outputs=[clssifier])
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  plot_model(model, show_shapes=True, to_file='lstm_autoencoder.png')
  model.summary()
  return model

model = create_model(128, 5)
model.load_weights("drive/My Drive/trained_models/composite_paper_5/encoderComposite_5.h5",by_name=True)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5, 128)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 5, 128)            131584
# _________________________________________________________________
# encoder (LSTM)               [(None, 128), (None, 128) 131584
# _________________________________________________________________
# dense (Dense)                (None, 7)                 903
# =================================================================
# Total params: 264,071
# Trainable params: 264,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, verbose=1, validation_split=0.05)
# Out:
# Epoch 1/10
# 60/60 [==============================] - 1s 25ms/step - loss: 1.5537 - accuracy: 0.4225 - val_loss: 1.2809 - val_accuracy: 0.6400
# Epoch 2/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.8282 - accuracy: 0.7626 - val_loss: 0.8705 - val_accuracy: 0.7700
# Epoch 3/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.4232 - accuracy: 0.8932 - val_loss: 0.6034 - val_accuracy: 0.8700
# Epoch 4/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.1994 - accuracy: 0.9593 - val_loss: 0.5628 - val_accuracy: 0.8600
# Epoch 5/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.1172 - accuracy: 0.9783 - val_loss: 0.4270 - val_accuracy: 0.9300
# Epoch 6/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0694 - accuracy: 0.9878 - val_loss: 0.4965 - val_accuracy: 0.9100
# Epoch 7/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0493 - accuracy: 0.9915 - val_loss: 0.4423 - val_accuracy: 0.9100
# Epoch 8/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0318 - accuracy: 0.9926 - val_loss: 0.4652 - val_accuracy: 0.9200
# Epoch 9/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.4110 - val_accuracy: 0.9200
# Epoch 10/10
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0199 - accuracy: 0.9952 - val_loss: 0.4661 - val_accuracy: 0.9200

# %%
def getFaceExpressionFromIndex(i):
  if (i == 0):
      return 'surprise'
  elif (i == 1):
      return 'smile'
  elif (i == 2):
      return 'sad'
  elif (i == 3):
      return 'anger'
  elif (i == 4):
      return 'fear'
  elif (i == 5):
      return 'disgust'
  elif (i == 6):
      return 'none'
  else:
      print(i)

# %%
test_predictions = model.predict(X_test)
correct = 0
for i in range(len(test_predictions)):
  truth = np.argmax(y_test[i])
  prediction = np.argmax(test_predictions[i])
  if truth == prediction:
    correct += 1
  else:
    print(f'Wrong classification, truth: {getFaceExpressionFromIndex(truth)}')
    print(f'Wrong classification, prediction: {getFaceExpressionFromIndex(prediction)}')
    print("---------------------------------------------------------------------------")
print(f'number of samples: {len(test_predictions)}')
print(f'correct: {correct}')
print(f'Accuracy of predicitons: {correct / len(test_predictions)}')
# Out:
# Wrong classification, truth: anger
# Wrong classification, prediction: sad
# ---------------------------------------------------------------------------
# Wrong classification, truth: sad
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: fear
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: disgust
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: fear
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: disgust
# Wrong classification, prediction: sad
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# number of samples: 222
# correct: 204
# Accuracy of predicitons: 0.918918918918919

# %%
# Here and below is the network to classify the encodings

# %%
from keras.models import load_model
from keras.models import model_from_json
import json

# load json and create model
json_file = open('drive/My Drive/trained_models/composite_paper_5/encoderComposite_5.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
encoder = model_from_json(loaded_model_json)
# load weights into new model
encoder.load_weights("drive/My Drive/trained_models/composite_paper_5/encoderComposite_5.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# Check here: better divinding to test/train set
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# Load encoding
X = np.load('drive/My Drive/dataset_5_frame_seq_faces/X_5.npy')
y = np.load('drive/My Drive/dataset_5_frame_seq_faces/Y_label_5.npy')

predictions = encoder.predict(X)


X_train, X_test, y_train, y_test = train_test_split(predictions, y, test_size = 0.1, random_state = 0)
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD


def classifier():
  model = Sequential()
  model.add(Dense(64, input_dim=128, activation='relu'))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(7, activation='softmax'))
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = classifier()
model.fit(X_train, y_train, epochs=50, verbose=1, validation_split=0.1)
# Out:
# Epoch 1/50
# 56/56 [==============================] - 0s 5ms/step - loss: 1.8469 - accuracy: 0.2518 - val_loss: 1.7690 - val_accuracy: 0.3450
# Epoch 2/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.6313 - accuracy: 0.3931 - val_loss: 1.6220 - val_accuracy: 0.4150
# Epoch 3/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.4560 - accuracy: 0.4897 - val_loss: 1.5257 - val_accuracy: 0.4350
# Epoch 4/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.2939 - accuracy: 0.5505 - val_loss: 1.4066 - val_accuracy: 0.5250
# Epoch 5/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.1570 - accuracy: 0.6220 - val_loss: 1.3256 - val_accuracy: 0.5550
# Epoch 6/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.0229 - accuracy: 0.6728 - val_loss: 1.2282 - val_accuracy: 0.6250
# Epoch 7/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.9131 - accuracy: 0.7197 - val_loss: 1.1723 - val_accuracy: 0.6300
# Epoch 8/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.8203 - accuracy: 0.7432 - val_loss: 1.0862 - val_accuracy: 0.6800
# Epoch 9/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.7247 - accuracy: 0.7789 - val_loss: 1.0540 - val_accuracy: 0.6800
# Epoch 10/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.6529 - accuracy: 0.8085 - val_loss: 0.9904 - val_accuracy: 0.6800
# Epoch 11/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.5820 - accuracy: 0.8275 - val_loss: 0.9323 - val_accuracy: 0.7350
# Epoch 12/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.5179 - accuracy: 0.8626 - val_loss: 0.9118 - val_accuracy: 0.7100
# Epoch 13/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4697 - accuracy: 0.8721 - val_loss: 0.8556 - val_accuracy: 0.7300
# Epoch 14/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4140 - accuracy: 0.8939 - val_loss: 0.8374 - val_accuracy: 0.7500
# Epoch 15/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.9146 - val_loss: 0.7954 - val_accuracy: 0.7650
# Epoch 16/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3286 - accuracy: 0.9241 - val_loss: 0.7451 - val_accuracy: 0.7600
# Epoch 17/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2995 - accuracy: 0.9313 - val_loss: 0.7403 - val_accuracy: 0.7750
# Epoch 18/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.9475 - val_loss: 0.7415 - val_accuracy: 0.7550
# Epoch 19/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2389 - accuracy: 0.9503 - val_loss: 0.7022 - val_accuracy: 0.7550
# Epoch 20/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.9620 - val_loss: 0.7099 - val_accuracy: 0.7600
# Epoch 21/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.9676 - val_loss: 0.6748 - val_accuracy: 0.7800
# Epoch 22/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1678 - accuracy: 0.9693 - val_loss: 0.6543 - val_accuracy: 0.7950
# Epoch 23/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1514 - accuracy: 0.9738 - val_loss: 0.6872 - val_accuracy: 0.7750
# Epoch 24/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1390 - accuracy: 0.9810 - val_loss: 0.6304 - val_accuracy: 0.8200
# Epoch 25/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1284 - accuracy: 0.9827 - val_loss: 0.6547 - val_accuracy: 0.7750
# Epoch 26/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1149 - accuracy: 0.9872 - val_loss: 0.6538 - val_accuracy: 0.7950
# Epoch 27/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9894 - val_loss: 0.6154 - val_accuracy: 0.8000
# Epoch 28/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0883 - accuracy: 0.9911 - val_loss: 0.6127 - val_accuracy: 0.8050
# Epoch 29/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9944 - val_loss: 0.6184 - val_accuracy: 0.8250
# Epoch 30/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9950 - val_loss: 0.6155 - val_accuracy: 0.8150
# Epoch 31/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9950 - val_loss: 0.6311 - val_accuracy: 0.8200
# Epoch 32/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 0.9966 - val_loss: 0.6357 - val_accuracy: 0.8150
# Epoch 33/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9961 - val_loss: 0.6259 - val_accuracy: 0.8200
# Epoch 34/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 0.9950 - val_loss: 0.6340 - val_accuracy: 0.8150
# Epoch 35/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9966 - val_loss: 0.6367 - val_accuracy: 0.8300
# Epoch 36/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9955 - val_loss: 0.6228 - val_accuracy: 0.8150
# Epoch 37/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 0.9983 - val_loss: 0.6426 - val_accuracy: 0.8400
# Epoch 38/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9983 - val_loss: 0.6387 - val_accuracy: 0.8350
# Epoch 39/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9983 - val_loss: 0.6849 - val_accuracy: 0.8150
# Epoch 40/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9966 - val_loss: 0.6621 - val_accuracy: 0.8400
# Epoch 41/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9966 - val_loss: 0.6479 - val_accuracy: 0.8300
# Epoch 42/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 0.9972 - val_loss: 0.6541 - val_accuracy: 0.8400
# Epoch 43/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 0.9978 - val_loss: 0.6472 - val_accuracy: 0.8450
# Epoch 44/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 0.9978 - val_loss: 0.6479 - val_accuracy: 0.8550
# Epoch 45/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9978 - val_loss: 0.6527 - val_accuracy: 0.8300
# Epoch 46/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 0.9966 - val_loss: 0.7085 - val_accuracy: 0.8300
# Epoch 47/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9972 - val_loss: 0.7041 - val_accuracy: 0.8250
# Epoch 48/50
# 56/56 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9972 - val_loss: 0.6572 - val_accuracy: 0.8300
# Epoch 49/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9978 - val_loss: 0.6679 - val_accuracy: 0.8450
# Epoch 50/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9961 - val_loss: 0.6709 - val_accuracy: 0.8450

# %%
def getFaceExpressionFromIndex(i):
  if (i == 0):
      return 'surprise'
  elif (i == 1):
      return 'smile'
  elif (i == 2):
      return 'sad'
  elif (i == 3):
      return 'anger'
  elif (i == 4):
      return 'fear'
  elif (i == 5):
      return 'disgust'
  elif (i == 6):
      return 'none'
  else:
      print(i)

# %%
test_predictions = model.predict(X_test)
correct = 0
for i in range(len(test_predictions)):
  truth = np.argmax(y_test[i])
  prediction = np.argmax(test_predictions[i])
  if truth == prediction:
    correct += 1
  else:
    print(f'Wrong classification, truth: {getFaceExpressionFromIndex(truth)}')
    print(f'Wrong classification, prediction: {getFaceExpressionFromIndex(prediction)}')
    print("---------------------------------------------------------------------------")

print(f'Accuracy of predicitons: {correct / len(test_predictions)}')
print(f'Got correct: {correct}')
print(f'Got wrong: {len(test_predictions) - correct}')
# Out:
# Wrong classification, truth: anger
# Wrong classification, prediction: sad
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: sad
# ---------------------------------------------------------------------------
# Wrong classification, truth: sad
# Wrong classification, prediction: disgust
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: fear
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: fear
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: fear
# ---------------------------------------------------------------------------
# Wrong classification, truth: fear
# Wrong classification, prediction: sad
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: surprise
# ---------------------------------------------------------------------------
# Wrong classification, truth: none
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: none
# ---------------------------------------------------------------------------
# Wrong classification, truth: anger
# Wrong classification, prediction: smile
# ---------------------------------------------------------------------------
# Wrong classification, truth: smile
# Wrong classification, prediction: sad
# ---------------------------------------------------------------------------
# Wrong classification, truth: disgust
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Wrong classification, truth: surprise
# Wrong classification, prediction: anger
# ---------------------------------------------------------------------------
# Accuracy of predicitons: 0.8648648648648649
# Got correct: 192
# Got wrong: 30

# %%
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

tsne = TSNE(n_components=2, random_state=0)

X_2d = tsne.fit_transform(X_train[:1000])

target_ids = range(0,7)
y_new = np.argmax(y_train,axis=1)

plt.figure(figsize=(20, 18))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k'
for i, c, label in zip(target_ids, colors, ["surprise", "smile","sad", "anger","fear", "disgust","none"]):
    plt.scatter(X_2d[y_new[:1000] == i, 0], X_2d[y_new[:1000] == i, 1], c=c, label=label)
plt.legend(prop={'size': 20})
plt.show()
